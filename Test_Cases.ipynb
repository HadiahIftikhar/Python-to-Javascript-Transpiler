# %% [markdown]
# # Lexer Test Cases:

# %%
test1 = "x = 10"

test2 = """def add(a, b):
return a + b"""

test3 = """if x > 10:
    print("Greater than 10")
else:
    print("Less than or equal to 10")"""

test3 = """
x = 42
y = 3.14
name = "John"
flag = True
result = x + y * 2
equal = x == y"""

test4 = """
for i in range(10):
    if i % 2 == 0:
        print("Even")
    else:
        print("Odd")

# While loop
count = 0
while count < 5:
    count += 1
"""

test5 = "x = 10 @"

test6 = """def test():
    x = 1
    y = 2  # Inconsistent indentation
"""

# %% [markdown]
# # Testing upto parser and AST

# %%
test1 = '''
def greet(name):
    return "Hello, " + name

message = greet("Fatima")
'''

test2 = '''
def add(x, y):
    return x + y

a = add(3, 5)
# '''

test3 = '''
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

def is_even(num):
    return num % 2 == 0

x = 5
fact = factorial(x)

if is_even(fact):
    print("Even factorial")
else:
    print("Odd factorial")

for i in range(3):
    result = factorial(i)
    print(result)
'''
test4 = '''
x = 7

if x % 2 == 0:
    print("Even")
else:
    print("Odd")
'''

test5 = '''
def square(n):
    return n * n

for i in range(4):
    print(square(i))
'''

test6 = '''
def classify(num):
    if num > 0:
        return "Positive"
    elif num < 0:
        return "Negative"
    else:
        return "Zero"

result = classify(3)
'''

# %% [markdown]
# # Semantic Analysis Test Cases

# %%
test1 = """
def square(x):
    return x * x

def add(a, b):
    result = a + b
    return result

value = 5
squared = square(value)
total = add(squared, 10)

def test():
    message = "All good!"
    return message
"""

test2='''
a = 5
b = 9
c = a + b
print(c)
'''

test3= """
def test(x):
    y = 2 + 3 * 4
    if True:
        return y + 10
    else:
        return y - 10

while False:
    print("Dead code")

result = test(5)

"""
#will show semantic errors
test4= """
def add(x, y):
    return x + y

result = add(5)  # Missing second argument
"""

#will show semantic errors
test5 = """
return 5
"""

test6 = """
def factorial(n):
    result = 1
    while n > 1:
        result = result * n
        n = n - 1
    return result

def is_even(x):
    return x % 2 == 0

def process(limit):
    i = 0
    total = 0
    while i < limit:
        f = factorial(i)
        if is_even(f):
            total = total + f
        else:
            total = total - f
        i = i + 1
    return total

result = process(5)
print(result)
"""

# %% [markdown]
# # Code Optimizer Test Cases

# %%
test1 = """
x = 2 + 3 * 4
y = 10 + 20 + 30
"""

test2 = """
if True:
    x = 10
    y = 20
else:
    x = 30
    y = 40

if False:
    print("This will be removed")
"""

test3 = """
while False:
    print("This loop will be removed")
    
x = 1
while True:
    x = x + 1
    break
"""

test4 = """
def calculate():
    a = 5 + 3 * 2
    b = 10 / 2
    c = a + b - (2 * 3)
    return c

result = calculate()
"""

test5 = """
def test(x):
    y = 2 + 3 * 4
    if True:
        return y + 10
    else:
        return y - 10

while False:
    print("Dead code")

result = test(5)
"""

test6 = """
def process_number(num):
    if num > 0:
        result = "positive"
    elif num < 0:
        result = "negative"  
    else:
        result = "zero"
    return result

answer = process_number(5)
print(answer)    
"""

# %% [markdown]
# # Code Generator Test Cases

# %%
test1 = """
def check_age(age):
    if age >= 18:
        status = "adult"
        can_vote = True
    else:
        status = "minor"
        can_vote = False
    print(status)
    return can_vote

result = check_age(20)
print(result)
"""

test2 = """
def process_number(num):
    if num > 0:
        result = "positive"
    elif num < 0:
        result = "negative"  
    else:
        result = "zero"
    return result

answer = process_number(5)
print(answer)
"""

test3 = """
def compare_values(x, y):
    if x > y:
        return x
    elif x < y:
        return y
    else:
        return x

def test_function():
    a = 10
    b = 20
    larger = compare_values(a, b)
    
    if larger > 15:
        print("Large number")
    else:
        print("Small number")

test_function()
"""
